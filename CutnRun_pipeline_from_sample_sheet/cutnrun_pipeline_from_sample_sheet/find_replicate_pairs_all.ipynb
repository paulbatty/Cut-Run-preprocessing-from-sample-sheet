# %%
#only relative paths are specified for reasons of data privacy

import csv

def read_barcodes_from_sample_sheet(sample_sheet_path):
    with open(sample_sheet_path, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        barcodes = [row['barcode'] for row in reader]
    return barcodes

def find_common_part(barcode1, barcode2):
    prefix1, replicate1 = barcode1.rsplit('-', 1)
    prefix2, replicate2 = barcode2.rsplit('-', 1)

    # Split the prefix by the experiment number (e.g., 929-001)
    parts1 = prefix1.split('-')
    parts2 = prefix2.split('-')

    # Find the common part of the prefix before and after the experiment number
    common_part_before = ''.join(c1 for c1, c2 in zip(parts1[:-1], parts2[:-1]) if c1 == c2)
    common_part_after = ''.join(c1 for c1, c2 in zip(parts1[1:], parts2[1:]) if c1 == c2)

    # If the replicates are different and both common parts are not empty,
    # return the combined common part
    if replicate1 != replicate2 and common_part_before and common_part_after:
        return f"{common_part_before}-{common_part_after}"

def find_replicate_pairs(barcodes):
    replicates = {}
    while barcodes:
        barcode1 = barcodes.pop(0)
        for barcode2 in barcodes:
            if barcode1 != barcode2:
                common_part = find_common_part(barcode1, barcode2)
                if common_part:
                    if common_part not in replicates:
                        replicates[common_part] = []
                    if barcode1 not in replicates[common_part] and barcode2 not in replicates[common_part]:
                        replicates[common_part].extend([barcode1, barcode2])
                        barcodes.remove(barcode2)
                        break
    return replicates

# Specify the path to the sample sheet
barcode_input_path = '*/sample_sheet.csv'

# Specify the output directory and file
output_directory = '*/pipeline_out/'

output_file = 'replicate_pairs.csv'

# Read barcodes from the sample sheet
barcodes = read_barcodes_from_sample_sheet(barcode_input_path)
print(f"Barcodes read from sample sheet: {barcodes}")

# Find the replicate pairs
replicate_pairs = find_replicate_pairs(barcodes)

# Print the number of replicate pairs found
num_replicate_pairs = len(replicate_pairs)
print(f"Number of replicate pairs found: {num_replicate_pairs}")

# Write the replicate pairs to the output CSV file
with open(f'{output_directory}/{output_file}', 'w', newline='') as csvfile:
    fieldnames = ['replicate1', 'replicate2']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for replicates in replicate_pairs.values():
        writer.writerow({'replicate1': replicates[0], 'replicate2': replicates[1]})

# Print the replicate pairs
for common_part, replicates in replicate_pairs.items():
    print(f"Common part: {common_part}, Replicate pair: {replicates}")
# Out:
# Barcodes read from sample sheet: ['MZ-CR140-Ex203-2-929-001-H3K9ac-R1', 'MZ-CR141-Ex203-3-929-001-H3K27ac-R1', 'MZ-CR142-Ex203-4-929-001-H3K4me3-R1', 'MZ-CR143-Ex203-5-929-001-KAT2A-R1', 'MZ-CR144-Ex203-6-929-001-Pol-II-S2P-R1', 'MZ-CR146-Ex203-8-929-001-H3K9ac-R2', 'MZ-CR147-Ex203-9-929-001-H3K27ac-R2', 'MZ-CR148-Ex203-10-929-001-H3K4me3-R2', 'MZ-CR149-Ex203-11-929-001-KAT2A-R2', 'MZ-CR150-Ex203-12-929-001-Pol-II-S2P-R2', 'MZ-CR152-Ex203-14-928-010-H3K9ac-R1', 'MZ-CR153-Ex203-15-928-010-H3K27ac-R1', 'MZ-CR154-Ex203-16-928-010-H3K4me3-R1', 'MZ-CR155-Ex203-17-928-010-KAT2A-R1', 'MZ-CR156-Ex203-18-928-010-Pol-II-S2P-R1', 'MZ-CR158-Ex203-20-928-010-H3K9ac-R2', 'MZ-CR159-Ex203-21-928-010-H3K27ac-R2', 'MZ-CR160-Ex203-22-928-010-H3K4me3-R2', 'MZ-CR161-Ex203-23-928-010-KAT2A-R2', 'MZ-CR162-Ex203-24-928-010-Pol-II-S2P-R2', 'MZ-CR164-Ex206-50-13B-24-H3K9ac-R1', 'MZ-CR165-Ex206-51-13B-24-H3K27ac-R1', 'MZ-CR166-Ex206-52-13B-24-H3K4me3-R1', 'MZ-CR167-Ex206-53-13B-24-KAT2A-R1', 'MZ-CR168-Ex206-54-13B-24-Pol-II-S2P-R1', 'MZ-CR170-Ex206-56-13B-24-H3K9ac-R2', 'MZ-CR171-Ex206-57-13B-24-H3K27ac-R2', 'MZ-CR172-Ex206-58-13B-24-H3K4me3-R2', 'MZ-CR173-Ex206-59-13B-24-KAT2A-R2', 'MZ-CR174-Ex206-60-13B-24-Pol-II-S2P-R2', 'MZ-CR176-Ex206-62-461-009-H3K9ac-R1', 'MZ-CR177-Ex206-63-461-009-H3K27ac-R1', 'MZ-CR178-Ex206-64-461-009-H3K4me3-R1', 'MZ-CR179-Ex206-65-461-009-KAT2A-R1', 'MZ-CR180-Ex206-66-461-009-Pol-II-S2P-R1', 'MZ-CR182-Ex206-68-461-009-H3K9ac-R2', 'MZ-CR183-Ex206-69-461-009-H3K27ac-R2', 'MZ-CR184-Ex206-70-461-009-H3K4me3-R2', 'MZ-CR185-Ex206-71-461-009-KAT2A-R2', 'MZ-CR186-Ex206-72-461-009-Pol-II-S2P-R2', 'MZ-CR188-Ex216-2-11A4-H3K9ac-R1', 'MZ-CR189-Ex216-3-11A4-H3K27ac-R1', 'MZ-CR190-Ex216-4-11A4-H3K4me3-R1', 'MZ-CR191-Ex216-5-11A4-KAT2A-R1', 'MZ-CR192-Ex216-6-11A4-Pol-II-S2P-R1', 'MZ-CR194-Ex216-8-11A4-H3K9ac-R2', 'MZ-CR195-Ex216-9-11A4-H3K27ac-R2', 'MZ-CR196-Ex216-10-11A4-H3K4me3-R2', 'MZ-CR197-Ex216-11-11A4-KAT2A-R2', 'MZ-CR198-Ex216-12-11A4-Pol-II-S2P-R2', 'MZ-CR200-Ex216-14-9A2-H3K9ac-R1', 'MZ-CR201-Ex216-15-9A2-H3K27ac-R1', 'MZ-CR202-Ex216-16-9A2-H3K4me3-R1', 'MZ-CR203-Ex216-17-9A2-KAT2A-R1', 'MZ-CR204-Ex216-18-9A2-Pol-II-S2P-R1', 'MZ-CR206-Ex216-20-9A2-H3K9ac-R2', 'MZ-CR207-Ex216-21-9A2-H3K27ac-R2', 'MZ-CR208-Ex216-22-9A2-H3K4me3-R2', 'MZ-CR209-Ex216-23-9A2-KAT2A-R2', 'MZ-CR210-Ex216-24-9A2-Pol-II-S2P-R2', 'MZ-CR212-Ex206-2-14A33-H3K9ac-R1', 'MZ-CR213-Ex206-3-14A33-H3K27ac-R1', 'MZ-CR214-Ex206-4-14A33-H3K4me3-R1', 'MZ-CR215-Ex206-5-14A33-KAT2A-R1', 'MZ-CR216-Ex206-6-14A33-Pol-II-S2P-R1', 'MZ-CR218-Ex206-8-14A33-H3K9ac-R2', 'MZ-CR219-Ex206-9-14A33-H3K27ac-R2', 'MZ-CR220-Ex206-10-14A33-H3K4me3-R2', 'MZ-CR221-Ex206-11-14A33-KAT2A-R2', 'MZ-CR222-Ex206-12-14A33-Pol-II-S2P-R2', 'MZ-CR224-Ex206-14-14C56-H3K9ac-R1', 'MZ-CR225-Ex206-15-14C56-H3K27ac-R1', 'MZ-CR226-Ex206-16-14C56-H3K4me3-R1', 'MZ-CR227-Ex206-17-14C56-KAT2A-R1', 'MZ-CR228-Ex206-18-14C56-Pol-II-S2P-R1', 'MZ-CR230-Ex206-20-14C56-H3K9ac-R2', 'MZ-CR231-Ex206-21-14C56-H3K27ac-R2', 'MZ-CR232-Ex206-22-14C56-H3K4me3-R2', 'MZ-CR233-Ex206-23-14C56-KAT2A-R2', 'MZ-CR234-Ex206-24-14C56-Pol-II-S2P-R2', 'MZ-CR236-Ex206-26-14B73-H3K9ac-R1', 'MZ-CR237-Ex206-27-14B73-H3K27ac-R1', 'MZ-CR238-Ex206-28-14B73-H3K4me3-R1', 'MZ-CR239-Ex206-29-14B73-KAT2A-R1', 'MZ-CR240-Ex206-30-14B73-Pol-II-S2P-R1', 'MZ-CR242-Ex206-32-14B73-H3K9ac-R2', 'MZ-CR243-Ex206-33-14B73-H3K27ac-R2', 'MZ-CR244-Ex206-34-14B73-H3K4me3-R2', 'MZ-CR245-Ex206-35-14B73-KAT2A-R2', 'MZ-CR246-Ex206-36-14B73-Pol-II-S2P-R2', 'MZ-CR248-Ex206-38-13B1-H3K9ac-R1', 'MZ-CR249-Ex206-39-13B1-H3K27ac-R1', 'MZ-CR250-Ex206-40-13B1-H3K4me3-R1', 'MZ-CR251-Ex206-41-13B1-KAT2A-R1', 'MZ-CR252-Ex206-42-13B1-Pol-II-S2P-R1', 'MZ-CR254-Ex206-44-13B1-H3K9ac-R2', 'MZ-CR255-Ex206-45-13B1-H3K27ac-R2', 'MZ-CR256-Ex206-46-13B1-H3K4me3-R2', 'MZ-CR257-Ex206-47-13B1-KAT2A-R2', 'MZ-CR258-Ex206-48-13B1-Pol-II-S2P-R2', 'MZ-CR260-Ex239-2-HAP1-WT-H3K9ac-R1', 'MZ-CR261-Ex239-3-HAP1-WT-H3K27ac-R1', 'MZ-CR262-Ex239-4-HAP1-WT-H3K4me3-R1', 'MZ-CR263-Ex239-5-HAP1-WT-KAT2A-R1', 'MZ- ...
# Number of replicate pairs found: 86
# Common part: MZEx203929001-Ex203929001H3K9ac, Replicate pair: ['MZ-CR140-Ex203-2-929-001-H3K9ac-R1', 'MZ-CR146-Ex203-8-929-001-H3K9ac-R2']
# Common part: MZEx203929001-Ex203929001H3K27ac, Replicate pair: ['MZ-CR141-Ex203-3-929-001-H3K27ac-R1', 'MZ-CR147-Ex203-9-929-001-H3K27ac-R2']
# Common part: MZEx203929001-Ex203929001H3K4me3, Replicate pair: ['MZ-CR142-Ex203-4-929-001-H3K4me3-R1', 'MZ-CR148-Ex203-10-929-001-H3K4me3-R2']
# Common part: MZEx203929001-Ex203929001KAT2A, Replicate pair: ['MZ-CR143-Ex203-5-929-001-KAT2A-R1', 'MZ-CR149-Ex203-11-929-001-KAT2A-R2']
# Common part: MZEx203929001PolII-Ex203929001PolIIS2P, Replicate pair: ['MZ-CR144-Ex203-6-929-001-Pol-II-S2P-R1', 'MZ-CR150-Ex203-12-929-001-Pol-II-S2P-R2']
# Common part: MZEx203928010-Ex203928010H3K9ac, Replicate pair: ['MZ-CR152-Ex203-14-928-010-H3K9ac-R1', 'MZ-CR158-Ex203-20-928-010-H3K9ac-R2']
# Common part: MZEx203928010-Ex203928010H3K27ac, Replicate pair: ['MZ-CR153-Ex203-15-928-010-H3K27ac-R1', 'MZ-CR159-Ex203-21-928-010-H3K27ac-R2']
# Common part: MZEx203928010-Ex203928010H3K4me3, Replicate pair: ['MZ-CR154-Ex203-16-928-010-H3K4me3-R1', 'MZ-CR160-Ex203-22-928-010-H3K4me3-R2']
# Common part: MZEx203928010-Ex203928010KAT2A, Replicate pair: ['MZ-CR155-Ex203-17-928-010-KAT2A-R1', 'MZ-CR161-Ex203-23-928-010-KAT2A-R2']
# Common part: MZEx203928010PolII-Ex203928010PolIIS2P, Replicate pair: ['MZ-CR156-Ex203-18-928-010-Pol-II-S2P-R1', 'MZ-CR162-Ex203-24-928-010-Pol-II-S2P-R2']
# Common part: MZEx20613B24-Ex20613B24H3K9ac, Replicate pair: ['MZ-CR164-Ex206-50-13B-24-H3K9ac-R1', 'MZ-CR170-Ex206-56-13B-24-H3K9ac-R2']
# Common part: MZEx20613B24-Ex20613B24H3K27ac, Replicate pair: ['MZ-CR165-Ex206-51-13B-24-H3K27ac-R1', 'MZ-CR171-Ex206-57-13B-24-H3K27ac-R2']
# Common part: MZEx20613B24-Ex20613B24H3K4me3, Replicate pair: ['MZ-CR166-Ex206-52-13B-24-H3K4me3-R1', 'MZ-CR172-Ex206-58-13B-24-H3K4me3-R2']
# Common part: MZEx20613B24-Ex20613B24KAT2A, Replicate pair: ['MZ-CR167-Ex206-53-13B-24-KAT2A-R1', 'MZ-CR173-Ex206-59-13B-24-KAT2A-R2']
# Common part: MZEx20613B24PolII-Ex20613B24PolIIS2P, Replicate pair: ['MZ-CR168-Ex206-54-13B-24-Pol-II-S2P-R1', 'MZ-CR174-Ex206-60-13B-24-Pol-II-S2P-R2']
# Common part: MZEx206461009-Ex206461009H3K9ac, Replicate pair: ['MZ-CR176-Ex206-62-461-009-H3K9ac-R1', 'MZ-CR182-Ex206-68-461-009-H3K9ac-R2']
# Common part: MZEx206461009-Ex206461009H3K27ac, Replicate pair: ['MZ-CR177-Ex206-63-461-009-H3K27ac-R1', 'MZ-CR183-Ex206-69-461-009-H3K27ac-R2']
# Common part: MZEx206461009-Ex206461009H3K4me3, Replicate pair: ['MZ-CR178-Ex206-64-461-009-H3K4me3-R1', 'MZ-CR184-Ex206-70-461-009-H3K4me3-R2']
# Common part: MZEx206461009-Ex206461009KAT2A, Replicate pair: ['MZ-CR179-Ex206-65-461-009-KAT2A-R1', 'MZ-CR185-Ex206-71-461-009-KAT2A-R2']
# Common part: MZEx206461009PolII-Ex206461009PolIIS2P, Replicate pair: ['MZ-CR180-Ex206-66-461-009-Pol-II-S2P-R1', 'MZ-CR186-Ex206-72-461-009-Pol-II-S2P-R2']
# Common part: MZEx21611A4-Ex21611A4H3K9ac, Replicate pair: ['MZ-CR188-Ex216-2-11A4-H3K9ac-R1', 'MZ-CR194-Ex216-8-11A4-H3K9ac-R2']
# Common part: MZEx21611A4-Ex21611A4H3K27ac, Replicate pair: ['MZ-CR189-Ex216-3-11A4-H3K27ac-R1', 'MZ-CR195-Ex216-9-11A4-H3K27ac-R2']
# Common part: MZEx21611A4-Ex21611A4H3K4me3, Replicate pair: ['MZ-CR190-Ex216-4-11A4-H3K4me3-R1', 'MZ-CR196-Ex216-10-11A4-H3K4me3-R2']
# Common part: MZEx21611A4-Ex21611A4KAT2A, Replicate pair: ['MZ-CR191-Ex216-5-11A4-KAT2A-R1', 'MZ-CR197-Ex216-11-11A4-KAT2A-R2']
# Common part: MZEx21611A4PolII-Ex21611A4PolIIS2P, Replicate pair: ['MZ-CR192-Ex216-6-11A4-Pol-II-S2P-R1', 'MZ-CR198-Ex216-12-11A4-Pol-II-S2P-R2']
# Common part: MZEx2169A2-Ex2169A2H3K9ac, Replicate pair: ['MZ-CR200-Ex216-14-9A2-H3K9ac-R1', 'MZ-CR206-Ex216-20-9A2-H3K9ac-R2']
# Common part: MZEx2169A2-Ex2169A2H3K27ac, Replicate pair: ['MZ-CR201-Ex216-15-9A2-H3K27ac-R1', 'MZ-CR207-Ex216-21-9A2-H3K27ac-R2']
# Common part: MZEx2169A2-Ex2169A2H3K4me3, Replicate pair: ['MZ-CR202-Ex216-16-9A2-H3K4me3-R1', 'MZ-CR208-Ex216-22-9A2-H3K4me3-R2']
# Common part: MZEx2169A2-Ex2169A2KAT2A, Replicate pair: ['MZ-CR203-Ex216-17-9A2-KAT2A-R1', 'MZ-CR209-Ex216-23-9A2-KAT2A-R2']
# Common part: MZEx2169A2PolII-Ex2169A2PolIIS2P, Replicate pair: ['MZ-CR204-Ex216-18-9A2-Pol-II-S2P-R1', 'MZ-CR210-Ex216-24-9A2-Pol-II-S2P-R2']
# Common part: MZEx20614A33-Ex20614A33H3K9ac, Replicate pair: ['MZ-CR212-Ex206-2-14A33-H3K9ac-R1', 'MZ-CR218-Ex206-8-14A33-H3K9ac-R2']
# Common part: MZEx20614A33-Ex20614A33H3K27ac, Replicate pair: ['MZ-CR213-Ex206-3-14A33-H3K27ac-R1', 'MZ-CR219-Ex206-9-14A33-H3K27ac-R2']
# Common part: MZEx20614A33-Ex20614A33H3K4me3, Replicate pair: ['MZ-CR214-Ex206-4-14A33-H3K4me3-R1', 'MZ-CR220-Ex206-10-14A33-H3K4me3-R2']
# Common part: MZEx20614A33-Ex20614A33KAT2A, Replicate pair: ['MZ-CR215-Ex206-5-14A33-KAT2A-R1', 'MZ-CR221-Ex206-11-14A33-KAT2A-R2']
# Common part: MZEx20614A33PolII-Ex20614A33PolIIS2P, Replicate pair: ['MZ-CR216-Ex206-6-14A33-Pol-II-S2P-R1', 'MZ-CR222-Ex206-12-14A33-Pol-II-S2P-R2']
# Common part: MZEx20614C56-Ex20614C56H3K9ac, Replicate pair: ['MZ-CR224-Ex206-14-14C56-H3K9ac-R1', 'MZ-CR230-Ex206-20-14C56-H3K9ac-R2']
# Common part: MZEx20614C56-Ex20614C56H3K27ac, Replicate pair: ['MZ-CR225-Ex206-15-14C56-H3K27ac-R1', 'MZ-CR231-Ex206-21-14C56-H3K27ac-R2']
# Common part: MZEx20614C56-Ex20614C56H3K4me3, Replicate pair: ['MZ-CR226-Ex206-16-14C56-H3K4me3-R1', 'MZ-CR232-Ex206-22-14C56-H3K4me3-R2']
# Common part: MZEx20614C56-Ex20614C56KAT2A, Replicate pair: ['MZ-CR227-Ex206-17-14C56-KAT2A-R1', 'MZ-CR233-Ex206-23-14C56-KAT2A-R2']
# Common part: MZEx20614C56PolII-Ex20614C56PolIIS2P, Replicate pair: ['MZ-CR228-Ex206-18-14C56-Pol-II-S2P-R1', 'MZ-CR234-Ex206-24-14C56-Pol-II-S2P-R2']
# Common part: MZEx20614B73-Ex20614B73H3K9ac, Replicate pair: ['MZ-CR236-Ex206-26-14B73-H3K9ac-R1', 'MZ-CR242-Ex206-32-14B73-H3K9ac-R2']
# Common part: MZEx20614B73-Ex20614B73H3K27ac, Replicate pair: ['MZ-CR237-Ex206-27-14B73-H3K27ac-R1', 'MZ-CR243-Ex206-33-14B73-H3K27ac-R2']
# Common part: MZEx20614B73-Ex20614B73H3K4me3, Replicate pair: ['MZ-CR238-Ex206-28-14B73-H3K4me3-R1', 'MZ-CR244-Ex206-34-14B73-H3K4me3-R2']
# Common part: MZEx20614B73-Ex20614B73KAT2A, Replicate pair: ['MZ-CR239-Ex206-29-14B73-KAT2A-R1', 'MZ-CR245-Ex206-35-14B73-KAT2A-R2']
# Common part: MZEx20614B73PolII-Ex20614B73PolIIS2P, Replicate pair: ['MZ-CR240-Ex206-30-14B73-Pol-II-S2P-R1', 'MZ-CR246-Ex206-36-14B73-Pol-II-S2P-R2']
# Common part: MZEx20613B1-Ex20613B1H3K9ac, Replicate pair: ['MZ-CR248-Ex206-38-13B1-H3K9ac-R1', 'MZ-CR254-Ex206-44-13B1-H3K9ac-R2']
# Common part: MZEx20613B1-Ex20613B1H3K27ac, Replicate pair: ['MZ-CR249-Ex206-39-13B1-H3K27ac-R1', 'MZ-CR255-Ex206-45-13B1-H3K27ac-R2']
# Common part: MZEx20613B1-Ex20613B1H3K4me3, Replicate pair: ['MZ-CR250-Ex206-40-13B1-H3K4me3-R1', 'MZ-CR256-Ex206-46-13B1-H3K4me3-R2']
# Common part: MZEx20613B1-Ex20613B1KAT2A, Replicate pair: ['MZ-CR251-Ex206-41-13B1-KAT2A-R1', 'MZ-CR257-Ex206-47-13B1-KAT2A-R2']
# Common part: MZEx20613B1PolII-Ex20613B1PolIIS2P, Replicate pair: ['MZ-CR252-Ex206-42-13B1-Pol-II-S2P-R1', 'MZ-CR258-Ex206-48-13B1-Pol-II-S2P-R2']
# Common part: MZEx239HAP1WT-Ex239HAP1WTH3K9ac, Replicate pair: ['MZ-CR260-Ex239-2-HAP1-WT-H3K9ac-R1', 'MZ-CR266-Ex239-8-HAP1-WT-H3K9ac-R2']
# Common part: MZEx239HAP1WT-Ex239HAP1WTH3K27ac, Replicate pair: ['MZ-CR261-Ex239-3-HAP1-WT-H3K27ac-R1', 'MZ-CR267-Ex239-9-HAP1-WT-H3K27ac-R2']
# Common part: MZEx239HAP1WT-Ex239HAP1WTH3K4me3, Replicate pair: ['MZ-CR262-Ex239-4-HAP1-WT-H3K4me3-R1', 'MZ-CR268-Ex239-10-HAP1-WT-H3K4me3-R2']
# Common part: MZEx239HAP1WT-Ex239HAP1WTKAT2A, Replicate pair: ['MZ-CR263-Ex239-5-HAP1-WT-KAT2A-R1', 'MZ-CR269-Ex239-11-HAP1-WT-KAT2A-R2']
# Common part: MZEx239HAP1WTPolII-Ex239HAP1WTPolIIS2P, Replicate pair: ['MZ-CR264-Ex239-6-HAP1-WT-Pol-II-S2P-R1', 'MZ-CR270-Ex239-12-HAP1-WT-Pol-II-S2P-R2']
# Common part: MZEx239HAP1Cas9-Ex239HAP1Cas9H3K9ac, Replicate pair: ['MZ-CR272-Ex239-14-HAP1-Cas9-H3K9ac-R1', 'MZ-CR278-Ex239-20-HAP1-Cas9-H3K9ac-R2']
# Common part: MZEx239HAP1Cas9-Ex239HAP1Cas9H3K27ac, Replicate pair: ['MZ-CR273-Ex239-15-HAP1-Cas9-H3K27ac-R1', 'MZ-CR279-Ex239-21-HAP1-Cas9-H3K27ac-R2']
# Common part: MZEx239HAP1Cas9-Ex239HAP1Cas9H3K4me3, Replicate pair: ['MZ-CR274-Ex239-16-HAP1-Cas9-H3K4me3-R1', 'MZ-CR280-Ex239-22-HAP1-Cas9-H3K4me3-R2']
# Common part: MZEx239HAP1Cas9-Ex239HAP1Cas9KAT2A, Replicate pair: ['MZ-CR275-Ex239-17-HAP1-Cas9-KAT2A-R1', 'MZ-CR281-Ex239-23-HAP1-Cas9-KAT2A-R2']
# Common part: MZEx239HAP1Cas9PolII-Ex239HAP1Cas9PolIIS2P, Replicate pair: ['MZ-CR276-Ex239-18-HAP1-Cas9-Pol-II-S2P-R1', 'MZ-CR282-Ex239-24-HAP1-Cas9-Pol-II-S2P-R2']
# Common part: MZEx2162D122H3K9ac-Ex2162D122H3K9acDMSO, Replicate pair: ['MZ-CR284-Ex216-2-2D122-H3K9ac-DMSO-R1', 'MZ-CR290-Ex216-8-2D122-H3K9ac-DMSO-R2']
# Common part: MZEx2162D122H3K27ac-Ex2162D122H3K27acDMSO, Replicate pair: ['MZ-CR285-Ex216-3-2D122-H3K27ac-DMSO-R1', 'MZ-CR291-Ex216-9-2D122-H3K27ac-DMSO-R2']
# Common part: MZEx2162D122H3K4me3-Ex2162D122H3K4me3DMSO, Replicate pair: ['MZ-CR286-Ex216-4-2D122-H3K4me3-DMSO-R1', 'MZ-CR292-Ex216-10-2D122-H3K4me3-DMSO-R2']
# Common part: MZEx2162D122KAT2A-Ex2162D122KAT2ADMSO, Replicate pair: ['MZ-CR287-Ex216-5-2D122-KAT2A-DMSO-R1', 'MZ-CR293-Ex216-11-2D122-KAT2A-DMSO-R2']
# Common part: MZEx2162D122PolIIS2P-Ex2162D122PolIIS2PDMSO, Replicate pair: ['MZ-CR288-Ex216-6-2D122-Pol-II-S2P-DMSO-R1', 'MZ-CR294-Ex216-12-2D122-Pol-II-S2P-DMSO-R2']
# Common part: MZEx2162D122H3K9ac-Ex2162D122H3K9acdTAG, Replicate pair: ['MZ-CR296-Ex216-14-2D122-H3K9ac-dTAG-R1', 'MZ-CR302-Ex216-20-2D122-H3K9ac-dTAG-R2']
# Common part: MZEx2162D122H3K27ac-Ex2162D122H3K27acdTAG, Replicate pair: ['MZ-CR297-Ex216-15-2D122-H3K27ac-dTAG-R1', 'MZ-CR303-Ex216-21-2D122-H3K27ac-dTAG-R2']
# Common part: MZEx2162D122H3K4me3-Ex2162D122H3K4me3dTAG, Replicate pair: ['MZ-CR298-Ex216-16-2D122-H3K4me3-dTAG-R1', 'MZ-CR304-Ex216-22-2D122-H3K4me3-dTAG-R2']
# Common part: MZEx2162D122KAT2A-Ex2162D122KAT2AdTAG, Replicate pair: ['MZ-CR299-Ex216-17-2D122-KAT2A-dTAG-R1', 'MZ-CR305-Ex216-23-2D122-KAT2A-dTAG-R2']
# Common part: MZEx2162D122PolIIS2P-Ex2162D122PolIIS2PdTAG, Replicate pair: ['MZ-CR300-Ex216-18-2D122-Pol-II-S2P-dTAG-R1', 'MZ-CR306-Ex216-24-2D122-Pol-II-S2P-dTAG-R2']
# Common part: MZEx2166D192H3K9ac-Ex2166D192H3K9acDMSO, Replicate pair: ['MZ-CR308-Ex216-26-6D192-H3K9ac-DMSO-R1', 'MZ-CR314-Ex216-32-6D192-H3K9ac-DMSO-R2']
# Common part: MZEx2166D192H3K27ac-Ex2166D192H3K27acDMSO, Replicate pair: ['MZ-CR309-Ex216-27-6D192-H3K27ac-DMSO-R1', 'MZ-CR315-Ex216-33-6D192-H3K27ac-DMSO-R2']
# Common part: MZEx2166D192H3K4me3-Ex2166D192H3K4me3DMSO, Replicate pair: ['MZ-CR310-Ex216-28-6D192-H3K4me3-DMSO-R1', 'MZ-CR316-Ex216-34-6D192-H3K4me3-DMSO-R2']
# Common part: MZEx2166D192KAT2A-Ex2166D192KAT2ADMSO, Replicate pair: ['MZ-CR311-Ex216-29-6D192-KAT2A-DMSO-R1', 'MZ-CR317-Ex216-35-6D192-KAT2A-DMSO-R2']
# Common part: MZEx2166D192PolIIS2P-Ex2166D192PolIIS2PDMSO, Replicate pair: ['MZ-CR312-Ex216-30-6D192-Pol-II-S2P-DMSO-R1', 'MZ-CR318-Ex216-36-6D192-Pol-II-S2P-DMSO-R2']
# Common part: MZEx2166D192H3K9ac-Ex2166D192H3K9acdTAG, Replicate pair: ['MZ-CR320-Ex216-38-6D192-H3K9ac-dTAG-R1', 'MZ-CR326-Ex216-44-6D192-H3K9ac-dTAG-R2']
# Common part: MZEx2166D192H3K27ac-Ex2166D192H3K27acdTAG, Replicate pair: ['MZ-CR321-Ex216-39-6D192-H3K27ac-dTAG-R1', 'MZ-CR327-Ex216-45-6D192-H3K27ac-dTAG-R2']
# Common part: MZEx2166D192H3K4me3-Ex2166D192H3K4me3dTAG, Replicate pair: ['MZ-CR322-Ex216-40-6D192-H3K4me3-dTAG-R1', 'MZ-CR328-Ex216-46-6D192-H3K4me3-dTAG-R2']
# Common part: MZEx2166D192KAT2A-Ex2166D192KAT2AdTAG, Replicate pair: ['MZ-CR323-Ex216-41-6D192-KAT2A-dTAG-R1', 'MZ-CR329-Ex216-47-6D192-KAT2A-dTAG-R2']
# Common part: MZEx2166D192PolIIS2P-Ex2166D192PolIIS2PdTAG, Replicate pair: ['MZ-CR324-Ex216-42-6D192-Pol-II-S2P-dTAG-R1', 'MZ-CR330-Ex216-48-6D192-Pol-II-S2P-dTAG-R2']
# Common part: MZEx2162D122HA-Ex2162D122HADMSO, Replicate pair: ['MZ-CR331-Ex216-49-2D122-HA-DMSO-R1', 'MZ-CR333-Ex216-51-2D122-HA-DMSO-R2']
# Common part: MZEx2162D122HA-Ex2162D122HAdTAG, Replicate pair: ['MZ-CR332-Ex216-50-2D122-HA-dTAG-R1', 'MZ-CR334-Ex216-52-2D122-HA-dTAG-R2']
# Common part: MZEx2166D192HA-Ex2166D192HADMSO, Replicate pair: ['MZ-CR335-Ex216-53-6D192-HA-DMSO-R1', 'MZ-CR337-Ex216-55-6D192-HA-DMSO-R2']
# Common part: MZEx2166D192HA-Ex2166D192HAdTAG, Replicate pair: ['MZ-CR336-Ex216-54-6D192-HA-dTAG-R1', 'MZ-CR338-Ex216-56-6D192-HA-dTAG-R2']
# Common part: MZEx239929001-Ex239929001SUPT7L, Replicate pair: ['MZ-CR340-Ex239-26-929-001-SUPT7L-R1', 'MZ-CR342-Ex239-28-929-001-SUPT7L-R2']
# Common part: MZEx239928010-Ex239928010SUPT7L, Replicate pair: ['MZ-CR344-Ex239-30-928-010-SUPT7L-R1', 'MZ-CR346-Ex239-32-928-010-SUPT7L-R2']
